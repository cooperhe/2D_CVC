# %%
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Monroe
    # http://xkcd.com/418/

    fig = plt.figure(figsize=(16,5))

    subplot(1,2,1)
    xlim(-0.4,0.4)
    ylim(0,0.6)
    plot([0,0.4],[0.6,0.6],'k-', linewidth=5)
    plot([-0.4,-0.4],[0,0.6],'k-', linewidth=5)
    plot([-0.4,0.4],[0,0],'k-', linewidth=5)
    plot([0.4,0.4],[0,0.6],'k-', linewidth=5)
    plot([-0.05,-0.05,0.05,0.05],[0,0.1,0.1,0],'k-', linewidth=2)
    plot([-0.05,0,0.05],[0.1,0.4,0.1],'r-', linewidth=2)
    ax = gca()  # gca stands for 'get current axis'
    #ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('data',0))
    ax.spines['left'].set_position(('data',0))
    ax.yaxis.set_ticks_position('left')
    annotate('$A_v$', xy=(-0.25, 0.58),size=20)
    annotate('$\dot{m}_f$', xy=(-0.1, 0.2),size=20)
plt.show()

# %%
EV=array([0.04,0.04,0.04,
          0.06,
          0.08])
EM=array([3.0,3.22,8.45,
          10.0,
          24.91])
BV=array([0.04,0.04,0.04,
          0.06,0.06,
          0.08,0.08])
BM=array([2.01,2.03,2.5,
          3.04,3.55,
          5.0,10.1])

GV=array([0.06,0.06,0.06,
          0.08,0.08,0.08])
GM=array([4.18,5.10,7.17,
          12.51,15.0,20.1])

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(BV,BM*27.2/15.,'sb', label='No extinction')
ax.plot(GV,GM*27.2/15.,'oy', markeredgewidth=1, markeredgecolor='red',label='Ghosting flame')
ax.plot(EV,EM*27.2/15.,'ow',markeredgewidth=2, markeredgecolor='red', label='Self-extinction')

ax.plot(array([0.03,0.04,0.06,0.08,0.09]),array([2.3,2.75,3.86,11.25,19])*27.2/15.,'--')
ax.plot(array([0.05,0.06,0.08,0.085]),array([3.3,8.59,22.5,29])*27.2/15.,'--r')

ax.set_yscale('log')
ax.set_yticks([1, 2,3,4,5,6,7,8,10, 20,30,40,50])
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
xlim(0.02,0.1)
ylim(3,60)
xlabel('$A_v/ m^2$',size=20)
ylabel('$\dot{m}_f/kw$',size=20)
legend(loc='upper left', numpoints=1)
grid()

# %%
EV=array([0.04,0.04,0.04,
          0.06,
          0.08])
EM=array([3.0,3.22,8.45,
          10.0,
          24.91])
BV=array([0.04,0.04,0.04,
          0.06,0.06,
          0.08,0.08])
BM=array([2.01,2.03,2.5,
          3.04,3.55,
          5.0,10.1])

GV=array([0.06,0.06,0.06,
          0.08,0.08,0.08])
GM=array([4.18,5.10,7.17,
          12.51,15.0,20.1])

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(BV,BM,'sb', label='No extinction')
ax.plot(GV,GM,'oy', markeredgewidth=1, markeredgecolor='red',label='Ghosting flame')
ax.plot(EV,EM,'ow',markeredgewidth=2, markeredgecolor='red', label='Self-extinction')

ax.plot(array([0.03,0.04,0.06,0.08,0.09]),array([2.3,2.75,3.86,11.25,19]),'--')
ax.plot(array([0.05,0.06,0.08,0.085]),array([3.3,8.59,22.5,29]),'--r')

ax.set_yscale('log')
ax.set_yticks([1, 2,3,4,5,6,7,8,10,15,20,25,30,40,50])
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
xlim(0.02,0.1)
ylim(1,30)
xlabel('$A_v/ m^2$',size=20)
ylabel('$\dot{m}_f/SLPM$',size=20)
legend(loc='upper left', numpoints=1)
grid()

# %%
import pandas as pd

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140506\\gas\\050605.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=35.2kw$')

#import data of experiemnt and simulation from files and plot them together
O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140506\\gas\\050604.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=28.4kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140506\\gas\\050602.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=21.4kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050701.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=17.7kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140506\\gas\\050606.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=7.1kw$')

legend(loc='lower center', numpoints=1)
rcParams.update({'legend.labelspacing':-0.1})
xlim(0,700)
ylim(0.1,0.21)
xlabel('$t/ s$',size=20)
ylabel('$\dot{Y}_0$',size=20)

# %%
O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050702.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=14.1kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050703.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=10.1kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050704.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=7.2kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050707.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=5.9kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050706.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=5.0kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140507\\gas\\050705.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=4.3kw$')

legend(loc='lower right', numpoints=1)
rcParams.update({'legend.labelspacing':-0.1})
xlim(0,700)
ylim(0.1,0.21)
xlabel('$t/ s$',size=20)
ylabel('$\dot{Y}_0$',size=20)

# %%
O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140429\\gas\\042905.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=4.2kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140429\\gas\\042904.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=3.5kw$')

O2_exp = pd.read_excel('E:\\2D_Ghosting_Experiment\\2D_CVC\\20140429\\gas\\042903.xlsx', 0, header=0)
Oxygen=O2_exp.O2.values
#data normalization
for i in range(len(Oxygen)):
    if Oxygen[i+1] < 20.7:
        break          
Oxygen=np.delete(Oxygen, range(i))
for i in range(1,len(Oxygen)):
    if Oxygen[i] > 20.6:
        break
Oxygen=np.delete(Oxygen, range(i,len(Oxygen)))
Oxygen=Oxygen/100
Time=np.arange(0,10*len(Oxygen),10)
plot(Time,Oxygen,label='$\dot{Q}_f=2.8kw$')

legend(loc='lower right', numpoints=1)
rcParams.update({'legend.labelspacing':-0.1})
xlim(0,700)
ylim(0.1,0.21)
xlabel('$t/ s$',size=20)
ylabel('$\dot{Y}_0$',size=20)

# %%
ls 'C:\\Users\\he\\Google Drive\\ipython_notebook\\2D_CVC'
# Out:
# The filename, directory name, or volume label syntax is incorrect.

# %%
import os

# %%
os.system('ls')
# Out:
# 1

# %%
cd E:\
# Out:
# E:\

# %%
cd E:\2D_Ghosting_Experiment/2D_CVC/20140506/gas/
# Out:
# E:\2D_Ghosting_Experiment\2D_CVC\20140506\gas

# %%
ls
# Out:
#  Volume in drive E is Work
#  Volume Serial Number is 3EBB-845C
#
#  Directory of E:\2D_Ghosting_Experiment\2D_CVC\20140506\gas
#
# 12/03/2014  12:51 PM    <DIR>          .
# 12/03/2014  12:51 PM    <DIR>          ..
# 05/05/2014  08:09 PM             2,584 050601.KM1
# 05/05/2014  08:10 PM             4,996 050601.XLS
# 05/06/2014  01:54 AM             5,848 050602.KM1
# 05/06/2014  01:54 AM            11,099 050602.XLS
# 12/03/2014  12:51 PM            22,267 050602.xlsx
# 05/06/2014  06:56 AM             2,108 050604.KM1
# 05/06/2014  06:56 AM             4,196 050604.XLS
# 12/02/2014  07:19 PM            14,587 050604.xlsx
# 05/06/2014  07:53 AM             1,088 050605.KM1
# 05/06/2014  08:52 AM             2,258 050605.XLS
# 12/03/2014  12:50 PM            12,394 050605.xlsx
# 05/06/2014  08:32 AM             4,624 050606.KM1
# 05/06/2014  08:32 AM             8,937 050606.XLS
# 12/03/2014  12:50 PM            19,595 050606.xlsx
#               14 File(s)        116,581 bytes
# ...
